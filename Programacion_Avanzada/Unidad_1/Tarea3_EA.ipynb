# %% [markdown]
# **Tarea 3 Programación Avanzada. CORRECION 4*A+B.**
#
#
# *Alumno: Eduardo Anza Figueroa*

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('A0ThoLFEY-U')

# %%
import modulo as md
# !python3 modulo.py

# %%
A = md.Punto2D(3,4)

# %%
A.a, A.b
# Out:
# (3, 4)

# %%
print(A)
# Out:
# (3, 4)

# %%
print(A(3))
# Out:
# (9, 12)

# %%
A = md.Punto2D(3,4)
B = md.Punto2D(5,6)

z1 = A+B
z2 = A-B

print(z1)
print(z2)
# Out:
# (8, 10)
# (-2, -2)

# %%
# CORRECION PARA OBTENER 4*A+B
z3 = 4*A+B
print(z3)
# Out:
# (17, 22)

# %%
A.grafica()

# %%
A.distancia1(B)
# Out:
# Tiempo de ejecución de distancia1: 1.8596649169921875e-05 segundos
# 'La distancia es de 2.8 unidades'

# %%
abs(A)
# Out:
# 5.0
